# %%
#importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independant = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependant = dataset[['charges']]

# %%
#spliting train and test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independant,dependant, test_size= 0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
#Parameter grid is the dictionary keys are names of parameters and values are list of settings to try
#Import GridSearch CV, then required model and enclose respective model parameters in param_grid
#assign variable to gridsearch parameters
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
              'splitter':['best','random'],'max_features':["sqrt","log2"]}
grid = GridSearchCV(DecisionTreeRegressor(),param_grid, refit = True,verbose = 3,n_jobs = -1)
#fitting model for grid search
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after turing
#grid.best_params_: This gives you the best parameters found during the grid search.
re = grid.cv_results_
print("R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}:

# %%
#Creating Dataframe from dictionary
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.030759      0.001070         0.001704        0.000417
# 1        0.001781      0.000119         0.001106        0.000097
# 2        0.003823      0.003170         0.001132        0.000071
# 3        0.001776      0.000203         0.001317        0.000297
# 4        0.002509      0.000485         0.001903        0.000615
# 5        0.002228      0.000386         0.001407        0.000517
# 6        0.002315      0.000261         0.001112        0.000025
# 7        0.001569      0.000079         0.000930        0.000042
# 8        0.008323      0.000935         0.001190        0.000247
# 9        0.005751      0.000595         0.001039        0.000031
# 10       0.008754      0.002402         0.001105        0.000052
# 11       0.005766      0.000445         0.001461        0.000403
# 12       0.002226      0.000150         0.000969        0.000044
# 13       0.002026      0.000231         0.001170        0.000145
# 14       0.002400      0.000149         0.001059        0.000042
# 15       0.001804      0.000028         0.000995        0.000038
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.742723
# 1   {'criterion': 'squared_error', 'max_features':...           0.698379
# 2   {'criterion': 'squared_error', 'max_features':...           0.785989
# 3   {'criterion': 'squared_error', 'max_features':...           0.746855
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.653566
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.670232
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.706566
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.751072
# 8   {'criterion': 'absolute_error', 'max_features'...           0.784635
# 9   {'criterion': 'absolute_error', 'max_features'...           0.672852
# 10  {'criterion': 'absolute_error', 'max_features'...           0.710870
# 11  {'criterion': 'absolute_error', 'max_features'...           0.674017
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.697204
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.654239
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.757800
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.634925
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.457156           0.551469           0.614210
# 1            0.617051           0.682238           0.491107
# 2            0.677344           0.533477           0.691075
# 3            0.536322           0.568346           0.599386
# 4            0.578621           0.521729           0.585960
# 5            0.661306           0.635440           0.607760
# 6            0.664967           0.658401           0.589211
# 7            0.661435           0.522295           0.539370
# 8            0.568350           0.624580           0.676024
# 9            0.387198           0.603654           0.568418
# 10           0.430618           0.472823           0.688951
# 11           0.502121           0.670006           0.548411
# 12           0.610424           0.696367           0.582135
# 13           0.565648           0.607926           0.454663
# 14           0.646187           0.629218           0.537909
# 15           0.659236           0.552845           0.535221
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.577924         0.588696        0.092930               14
# 1            0.605158         0.618786        0.073283                6
# 2            0.681019         0.673781        0.080796                1
# 3            0.548663         0.599915        0.076497               10
# 4            0.652139         0.598403        0.049710               11
# 5            0.531037         0.621155        0.050051                5
# 6            0.446077         0.613044        0.091592                7
# 7            0.565477         0.607930        0.086242                8
# 8            0.631972         0.657112        0.072373                3
# 9            0.544118         0.555248        0.094564               16
# 10           0.659247         0.592502        0.116874               13
# 11           0.570524         0.593016        0.068185               12
# 12           0.613863         0.639999        0.047657                4
# 13           0.554484         0.567392        0.066427               15
# 14           0.737872         0.661797        0.079571                2
# 15           0.645218         0.605489        0.051074                9

# %%
#Get inputs
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
child_input = int(input("Children:"))
smoker_input = int(input("Smoker Yes 0 or 1:"))
sex_input = int(input("Sex Male 0 or 1:"))
# Out:
# Age: 33
# BMI: 27.1
# Children: 3
# Smoker Yes 0 or 1: 1
# Sex Male 0 or 1: 0

# %%
#Assign grid.predict from input lists
Future_Prediction = grid.predict([[age_input,bmi_input,child_input,smoker_input,sex_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[12592.5345]
